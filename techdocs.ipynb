# %% [markdown]
# <a href="https://colab.research.google.com/github/binnyharsh/technical-discussion/blob/main/techdocs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##### Ingest

# %%
def hello():
  return "hi"
hello()
# Out:
# 'hi'

# %% [markdown]
# #### EDA

# %% [markdown]
# ### This is a markdown heading
#
# * one
# * two

# %% [markdown]
# ### Conclusion
#
# ![Capture.JPG](data:image/jpeg;base64,...)
